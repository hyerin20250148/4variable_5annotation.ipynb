# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerin20250148/4variable_5annotation.ipynb/blob/main/42%2C43.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
male=['슈퍼맨','심봉사','로미오','이몽룡','마루치']
female=['원더우먼','뺑덕어멈','줄리엣','성춘향','아라치']
couples=zip(male,female)
for couple in couples:
        print(couple)
# Out:
# ('슈퍼맨', '원더우먼')
# ('심봉사', '뺑덕어멈')
# ('로미오', '줄리엣')
# ('이몽룡', '성춘향')
# ('마루치', '아라치')

# %%
male=['슈퍼맨','심봉사','로미오']
female=['원더우먼','뺑덕어멈','줄리엣','성춘향','아라치']
for couple in zip(male,female):
  print(couple)
# Out:
# ('슈퍼맨', '원더우먼')
# ('심봉사', '뺑덕어멈')
# ('로미오', '줄리엣')

# %%
listData=[0,1,2,3,4]
print(all(listData))
print(any(listData))
# Out:
# False
# True

# %%
tupleData=(0,False,'',[],(),{},None)
print(all(tupleData))
print(any(tupleData))
# Out:
# False
# False
