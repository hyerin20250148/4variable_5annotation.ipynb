# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerin20250148/4variable_5annotation.ipynb/blob/main/50%2C51.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
listData=[9.96,1.27,5.07,6.45,8.38,9.29,7.73,3.71,0.93]
print(max(listData))
print(min(listData))
# Out:
# 9.96
# 0.93

# %%
strData='AlotofThingsOccurEachday'
print(max(strData))
print(min(strData))
# Out:
# y
# A

# %%
list1=[1,2,3,'a','b','c']
# print(max(list1)) # Original line causing the error

# Fix: Filter out non-numeric values to find the maximum among numbers
numeric_values = [x for x in list1 if isinstance(x, (int, float))]
if numeric_values:
    print(max(numeric_values))
else:
    print("리스트에 숫자 값이 없습니다.") # No numeric values in the list
# Out:
# 3

# %%
lyrics='A lot of things occur each day! every day!'
print(lyrics.count('o'))
# Out:
# 3

# %%
lyrics='A lot of things occur each day! every day!'
print(lyrics.count('day'))
# Out:
# 2

# %%
listData=[1,5,1,4,8,4,12,1,0,9,9,7,4,3,6,7,3,2]
print(listData.count(1))
# Out:
# 3
