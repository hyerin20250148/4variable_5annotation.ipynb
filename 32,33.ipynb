# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerin20250148/4variable_5annotation.ipynb/blob/main/32%2C33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
h1=hex(97)
h2=hex(98)
print(h1)
print(h2)
# Out:
# 0x61
# 0x62

# %%
print(h1+h2)
# Out:
# 0x610x62

# %%
hexStr1='0x11'
hexStr2='0x2a'
int1=int(hexStr1,base=16)
int2=int(hexStr2,base=16)
hexAnswer=hex(int1+int2)
hexAnswer=hex(int1+int2)
print(f'{hexStr1}+{hexStr2} ={hexAnswer}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2371259199.py in <cell line: 0>()
#       5 hexAnswer=hex(int1+int2)
#       6 hexAnswer=hex(int1+int2)
# ----> 7 print(f'{hexStr1}+{hexSrt2} ={hexAnswer}')
#
# NameError: name 'hexSrt2' is not defined

# %%
b1=bin(97)
b2=bin(98)
print(b1)
print(b2)
# Out:
# 0b1100001
# 0b1100010

# %%
print(b1+b2)
# Out:
# 0b11000010b1100010

# %%
binStr1='0b1011'
binStr2='0b1001'
int1=int(binStr1,base=2)
int2=int(binStr2,base=2)
binAnswer=bin(int1+int2)
print(f'{binStr1}+{binStr2}={binAnswer}')
# Out:
# 0b1011+0b1001=0b10100
