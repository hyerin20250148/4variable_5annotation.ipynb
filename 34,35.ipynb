# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerin20250148/4variable_5annotation.ipynb/blob/main/34%2C35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
listData=[1,2,3,4]
iterator1=listData.__iter__()
print(type(iterator1))
# Out:
# <class 'list_iterator'>

# %%
listData=[1,2,3,4]
iterator2=iter(listData)
print(type(iterator2))
# Out:
# <class 'list_iterator'>

# %%
print(next(iterator2))
print(next(iterator2))
print(next(iterator2))
print(next(iterator2))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-3257622498.py in <cell line: 0>()
# ----> 1 print(next(iterator2))
#       2 print(next(iterator2))
#       3 print(next(iterator2))
#       4 print(next(iterator2))
#
# StopIteration:
