# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerin20250148/4variable_5annotation.ipynb/blob/main/52%2C53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lyrics='A lot of things occur each day! every day!'
flag='things'in lyrics
print(flag)
# Out:
# True

# %%
lyrics='A lot of thing occur each day! every day!'
flag='today'not in lyrics
print(flag)
# Out:
# True

# %%
fruits=('사과','배','참외','수박','배','오렌지')
fruit=fruits.index('배',3)
print(f'배는 {fruit+1}번째 과일입니다.')
# Out:
# 배는 5번째 과일입니다.

# %%
fruits=('사과','배','참외','수박','배','오렌지')
pos=fruits.index('사과')
print(f'사과는{pos+1}번째 과일입니다.')
# Out:
# 사과는1번째 과일입니다.
