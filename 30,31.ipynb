# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerin20250148/4variable_5annotation.ipynb/blob/main/30%2C31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ret=round(42.195)
print(ret)
# Out:
# 42

# %%
ret=round(42.195, 0)
print(ret)
# Out:
# 42.0

# %%
ret=round(42.195, 1)
print(ret)
# Out:
# 42.2

# %%
floatData=1234.5
intData=int(floatData)
print(f'intData{intData}자료형은{type(intData)}입니다')
# Out:
# intData1234자료형은<class 'int'>입니다

# %%
strData='1234'
intData=int(strData)
print(f'intData{intData}자료형은{type(intData)}입니다.')
# Out:
# intData1234자료형은<class 'int'>입니다.

# %%
print(float('2E5'))
print(float('2e-3'))
# Out:
# 200000.0
# 0.002
