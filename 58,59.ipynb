# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerin20250148/4variable_5annotation.ipynb/blob/main/58%2C59.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers=[1,1,3,1,1,5,6,2,0,7]
if 1 in numbers:
  numbers.remove(1)
print(numbers)
# Out:
# [1, 3, 1, 1, 5, 6, 2, 0, 7]

# %%
numbers=[1,1,3,1,1,5,6,2,0,7]
while 1 in numbers:
  numbers.remove(1)
print(numbers)
# Out:
# [3, 5, 6, 2, 0, 7]

# %%
fruits=['사과','배','오렌지','수박','참외']
if '딸기' in fruits:
  fruits.remove('딸기')

# %%
fruit=['사과','배','오렌지','수박','참외']
del fruits[:]
print(fruits)
# Out:
# []
