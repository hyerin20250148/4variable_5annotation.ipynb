# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerin20250148/4variable_5annotation.ipynb/blob/main/44%2C45.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
listData=[42,1,39,27,44,8]
ret1=sorted(listData)
ret2=sorted(listData,reverse=True)
print(ret1)
print(ret2)
print(listData)
# Out:
# [1, 8, 27, 39, 42, 44]
# [44, 42, 39, 27, 8, 1]
# [42, 1, 39, 27, 44, 8]

# %%
tupleData=('사과','배','오렌지','수박','참외')
ret=sorted(tupleData)
print(ret)
# Out:
# ['배', '사과', '수박', '오렌지', '참외']

# %%
strData='I love python!'
ret=sorted(strData)
print(ret)
# Out:
# [' ', ' ', '!', 'I', 'e', 'h', 'l', 'n', 'o', 'o', 'p', 't', 'v', 'y']

# %%
population={'김씨':2834,'이씨':2288,'박씨':1889}
ret=sorted(population)
print(ret)
# Out:
# ['김씨', '박씨', '이씨']
