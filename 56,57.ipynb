# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerin20250148/4variable_5annotation.ipynb/blob/main/56%2C57.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
solarsys=['태양','수성','금성','지구','화성','목성','토성','천왕성','해왕성']
solarsys[3]='Earth'
print(solarsys)
# Out:
# ['태양', '수성', '금성', 'Earth', '화성', '목성', '토성', '천왕성', '해왕성']

# %%
fruits=['사과','배','오렌지','수박','참외']
del fruits[1]
print(fruits)
del fruits[-1]
print(fruits)
# Out:
# ['사과', '오렌지', '수박', '참외']
# ['사과', '오렌지', '수박']

# %%
solarsys=['태양','수성','금성','지구','화성','소행성대','목성','토성']
del solarsys[4:6]
print(solarsys)
# Out:
# ['태양', '수성', '금성', '지구', '목성', '토성']

# %%
del solarsys[:]
print(solarsys)
# Out:
# []

# %%
fruits=['사과','배','오렌지','수박','참외']
print(fruits)
# Out:
# ['사과', '배', '오렌지', '수박', '참외']
